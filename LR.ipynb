# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import time

# %%
data = pd.read_csv('data.csv')
data
# Out:
#        Unnamed: 0                                              title  \
# 0           12524  BREAKING FL VOTER FRAUD ALERT: “Tens Of Thousa...
# 1            4388  U.S. strikes in Syria show resolve against che...
# 2           15398  [RAW VIDEO] WHAT JEB BUSH JUST TOLD A HISPANIC...
# 3            6746   Oklahoma GOP Just Took Their War On Women To ...
# 4              81   Conservative ‘Christian’ Leader Kept A Sexual...
# ...           ...                                                ...
# 44893        6571  Senator Graham says enough is enough on Russia...
# 44894         107   This Old Mike Pence Tweet Sure Is Uncomfortab...
# 44895       10584  BIKERS FOR TRUMP Bring Important Message and H...
# 44896       13517  TAKE THE POLL: Tell Us Who You Think Will Be T...
# 44897         951   Hannity Defends Trump With Psychotic Threat T...
#
#                                                     text       subject  label  \
# 0      https://twitter.com/TEN_GOP/status/79389017105...      politics      1
# 1      BRUSSELS (Reuters) - European Council Presiden...  politicsNews      0
# 2      Bush spoke to a hispanic audience in central F...      politics      1
# 3      Republicans in Oklahoma just took their war on...          News      1
# 4      Conservatives should shun Tony Perkins for thi...          News      1
# ...                                                  ...           ...    ...
# 44893  RIGA (Reuters) - A U.S. senator said on Wednes...  politicsNews      0
# 44894  GOP candidate Roy Moore is accused of sexually...          News      1
# 44895  Millions and millions of dollars from outside ...      politics      1
# 44896  Trump will announce his VP pick tomorrow. Rumo...      politics      1
# 44897  One of Donald Trump s biggest fans, Fox News h...          News      1
#
#                                         training_feature
# 0      BREAKING FL VOTER FRAUD ALERT: “Tens Of Thousa...
# 1      U.S. strikes in Syria show resolve against che...
# 2      [RAW VIDEO] WHAT JEB BUSH JUST TOLD A HISPANIC...
# 3       Oklahoma GOP Just Took Their War On Women To ...
# 4       Conservative ‘Christian’ Leader Kept A Sexual...
# ...                                                  ...
# 44893  Senator Graham says enough is enough on Russia...
# 44894   This Old Mike Pence Tweet Sure Is Uncomfortab...
# 44895  BIKERS FOR TRUMP Bring Important Message and H...
# 44896  TAKE THE POLL: Tell Us Who You Think Will Be T...
# 44897   Hannity Defends Trump With Psychotic Threat T...
#
# [44898 rows x 6 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X= data['training_feature'].values
y = data['label']

# %%
vectorizer= TfidfVectorizer()
X=vectorizer.fit_transform(X)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.2, stratify=y, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
import pickle
pickle.dump(model, open('model.pkl','wb'))

# %%
data
# Out:
#        Unnamed: 0                                              title  \
# 0           12524  BREAKING FL VOTER FRAUD ALERT: “Tens Of Thousa...
# 1            4388  U.S. strikes in Syria show resolve against che...
# 2           15398  [RAW VIDEO] WHAT JEB BUSH JUST TOLD A HISPANIC...
# 3            6746   Oklahoma GOP Just Took Their War On Women To ...
# 4              81   Conservative ‘Christian’ Leader Kept A Sexual...
# ...           ...                                                ...
# 44893        6571  Senator Graham says enough is enough on Russia...
# 44894         107   This Old Mike Pence Tweet Sure Is Uncomfortab...
# 44895       10584  BIKERS FOR TRUMP Bring Important Message and H...
# 44896       13517  TAKE THE POLL: Tell Us Who You Think Will Be T...
# 44897         951   Hannity Defends Trump With Psychotic Threat T...
#
#                                                     text       subject  label  \
# 0      https://twitter.com/TEN_GOP/status/79389017105...      politics      1
# 1      BRUSSELS (Reuters) - European Council Presiden...  politicsNews      0
# 2      Bush spoke to a hispanic audience in central F...      politics      1
# 3      Republicans in Oklahoma just took their war on...          News      1
# 4      Conservatives should shun Tony Perkins for thi...          News      1
# ...                                                  ...           ...    ...
# 44893  RIGA (Reuters) - A U.S. senator said on Wednes...  politicsNews      0
# 44894  GOP candidate Roy Moore is accused of sexually...          News      1
# 44895  Millions and millions of dollars from outside ...      politics      1
# 44896  Trump will announce his VP pick tomorrow. Rumo...      politics      1
# 44897  One of Donald Trump s biggest fans, Fox News h...          News      1
#
#                                         training_feature
# 0      BREAKING FL VOTER FRAUD ALERT: “Tens Of Thousa...
# 1      U.S. strikes in Syria show resolve against che...
# 2      [RAW VIDEO] WHAT JEB BUSH JUST TOLD A HISPANIC...
# 3       Oklahoma GOP Just Took Their War On Women To ...
# 4       Conservative ‘Christian’ Leader Kept A Sexual...
# ...                                                  ...
# 44893  Senator Graham says enough is enough on Russia...
# 44894   This Old Mike Pence Tweet Sure Is Uncomfortab...
# 44895  BIKERS FOR TRUMP Bring Important Message and H...
# 44896  TAKE THE POLL: Tell Us Who You Think Will Be T...
# 44897   Hannity Defends Trump With Psychotic Threat T...
#
# [44898 rows x 6 columns]
